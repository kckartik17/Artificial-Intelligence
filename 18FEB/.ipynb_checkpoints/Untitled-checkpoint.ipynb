# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
ab=pd.read_excel('Data.xlsx')

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 271 entries, nan to nan
# Data columns (total 26 columns):
# RE California Database    270 non-null object
# Unnamed: 1                268 non-null object
# Unnamed: 2                196 non-null object
# Unnamed: 3                196 non-null object
# Unnamed: 4                268 non-null object
# Unnamed: 5                268 non-null object
# Unnamed: 6                268 non-null object
# Unnamed: 7                268 non-null object
# Unnamed: 8                196 non-null object
# Unnamed: 9                0 non-null float64
# Unnamed: 10               197 non-null object
# Unnamed: 11               196 non-null object
# Unnamed: 12               196 non-null object
# Unnamed: 13               196 non-null object
# Unnamed: 14               179 non-null object
# Unnamed: 15               179 non-null object
# Unnamed: 16               179 non-null object
# Unnamed: 17               179 non-null object
# ...

# %%
ab.mean()
# Out:
# Unnamed: 9   NaN
# dtype: float64

# %%
ab.median()
# Out:
# Unnamed: 9   NaN
# dtype: float64

# %%
ab.describe()
# Out:
#        Unnamed: 9
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
ab.mode()
# Out:
#    RE California Database Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                    1002          3       2007         11  Apartment
# 1                    1003        NaN        NaN        NaN        NaN
# 2                    1008        NaN        NaN        NaN        NaN
# 3                    1009        NaN        NaN        NaN        NaN
# 4                    1019        NaN        NaN        NaN        NaN
# 5                    1042        NaN        NaN        NaN        NaN
# 6                    1047        NaN        NaN        NaN        NaN
# 7                    2052        NaN        NaN        NaN        NaN
# 8                    3007        NaN        NaN        NaN        NaN
# 9                    3029        NaN        NaN        NaN        NaN
# 10                   3031        NaN        NaN        NaN        NaN
# 11                   3038        NaN        NaN        NaN        NaN
# ...

# %%
from scipy.stats import variation

# %%
variation(ab, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b95ae931aec2> in <module>
# ----> 1 variation(ab, axis=1)
#
# NameError: name 'variation' is not defined
