# %%
import numpy as np
import pandas as pd

# %%
ice = pd.read_csv('911B.csv')

# %%
ice
# Out:
#        Unnamed: 0        lat        lng  \
# 0           13580  40.117121 -75.355986
# 1           36771  40.209955 -75.464304
# 2           30081  40.244912 -75.644363
# 3           21990  40.302220 -75.406636
# 4           78864  40.120227 -75.330195
# 5           51843  40.178511 -75.192067
# 6           77219  40.154698 -75.139243
# 7           65946  40.155811 -75.485411
# 8           81476  40.214581 -75.289200
# 9           97049  40.251492 -75.603350
# 10          28528  40.229008 -75.387853
# 11          33635  40.398823 -75.490660
# 12          63201  40.156847 -75.101994
# 13          41211  40.129538 -75.324636
# 14          88434  40.152535 -75.114405
# 15          29279  40.214977 -75.499712
# 16          55952  40.181332 -75.105064
# 17           2928  40.118960 -75.351356
# 18          76351  40.075603 -75.107809
# 19          89786  40.125582 -75.320525
# 20          68767  40.185573 -75.095442
# 21          25510  40.250191 -75.277571
# ...

# %%
ice['twp'].value_counts()
# Out:
# LOWER MERION         6737
# ABINGTON             4842
# NORRISTOWN           4642
# UPPER MERION         4174
# CHELTENHAM           3658
# POTTSTOWN            3341
# UPPER MORELAND       2749
# LOWER PROVIDENCE     2572
# PLYMOUTH             2561
# HORSHAM              2377
# MONTGOMERY           2166
# UPPER DUBLIN         2149
# WHITEMARSH           2020
# UPPER PROVIDENCE     1846
# SPRINGFIELD          1798
# LIMERICK             1796
# WHITPAIN             1689
# EAST NORRITON        1623
# HATFIELD TOWNSHIP    1404
# LANSDALE             1373
# LOWER POTTSGROVE     1333
# LOWER MORELAND       1330
# TOWAMENCIN           1305
# LOWER GWYNEDD        1294
# WEST NORRITON        1285
# UPPER GWYNEDD        1173
# LOWER SALFORD        1054
# FRANCONIA            1054
# CHESTER COUNTY        895
# DOUGLASS              754
#                      ...
# UPPER HANOVER         448
# UPPER POTTSGROVE      445
# BRIDGEPORT            434
# WEST POTTSGROVE       423
# ...

# %%
type(ice['timeStamp'].loc[0])
# Out:
# str

# %%
ice['timeStamp'].to_datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-bdea5256a88d> in <module>
# ----> 1 ice['timeStamp'].to_datetime
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'to_datetime'
